# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
from src import soporte_correlacion as sp_corr

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("files/world_data_full_apply.csv") 
df.head(2)
# Out:
#    Unnamed: 0      country  density abbreviation  agricultural_land  \
# 0           0  Afghanistan     60.0           AF               58.1
# 1           1      Albania    105.0           AL               43.1
#
#    land_area  armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0    652.230              323.0       32.49          93.0              Kabul
# 1     28.748                9.0       11.78         355.0             Tirana
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'density', 'abbreviation', 'agricultural_land',
#        'land_area', 'armed_forces_size', 'birth_rate', 'calling_code',
#        'capital/major_city', 'co2-emissions', 'cpi', 'cpi_change',
#        'currency-code', 'fertility_rate', 'forested_area', 'gasoline_price',
#        'gdp', 'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent'],
#       dtype='str')

# %%
#coeficiente de correlacion de Pearson entre: fertility_rate y life_expectancy
coeficiente = df['fertility_rate'].corr(df['life_expectancy'])
coeficiente
# Out:
# np.float64(-0.849152810736001)

# %%
sns.scatterplot(data=df, x="fertility_rate", y="life_expectancy")
#correlacion negativa: Cuando la fertilidad es baja, la esperanza de vida es alta.
#moderada
#En general, cuando la tasa de fertilidad es alta, la esperanza de vida disminuye
# Out:
# <Axes: xlabel='fertility_rate', ylabel='life_expectancy'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
variables = ['fertility_rate', 'life_expectancy', 'infant_mortality']
df[variables].corr()
# Out:
#                   fertility_rate  life_expectancy  infant_mortality
# fertility_rate          1.000000        -0.849153          0.852653
# life_expectancy        -0.849153         1.000000         -0.924675
# infant_mortality        0.852653        -0.924675          1.000000

# %%
variables = ['gdp', 'co2-emissions', 'population']

sns.heatmap(df[variables].corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# co2-emissions y gdp son las variables que tienen correlacion mas alta con 0.48

# %%
sns.heatmap(df_correlaciones)
# Out:
# <Axes: >
