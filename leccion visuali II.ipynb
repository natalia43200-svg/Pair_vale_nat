# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_c = df.groupby("continent")["country"].count().reset_index()
df_c
# Out:
#          continent  country
# 0           Africa       53
# 1             Asia       45
# 2  Central America       20
# 3           Europe       47
# 4    North America        2
# 5          Oceania       14
# 6    South America       13

# %%
#Cual es el continente con la mayor cantidad de paises en el conjunto de datos? Proporciona el porcentaje de paises en ese continente
#comprobacion 1
plt.pie(data=df_c, labels="continent", x="country", autopct="%1.1f%%");

# %%
sns.barplot(data=df_c, x="country", y="continent", palette="viridis")
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_15144\2697564172.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_c, x="country", y="continent", palette="viridis");

# %%
df["forested_area"].unique()
# Out:
# array([ 2.1, 28.1,  0.8, 34. , 46.3, 22.3,  9.8, 11.7, 16.3, 46.9, 14.1,
#        51.4, 11. , 14.7, 42.6, 22.6, 59.7, 37.8, 72.5, 50.3, 42.7, 18.9,
#        58.9, 72.1, 35.4, 19.3, 10.9, 32.7, 22.5, 52.9, 39.3, 38.2, 35.6,
#         3.8, 24.3, 22.4, 52.7, 19.7, 65.4, 54.6, 34.4, 31.3, 18.7, 34.6,
#        67.2,  0.2, 57.4, 41.7, 50.2,  0.1, 12.6, 55.5, 14.9, 51.3,  nan,
#        12.5, 55.9, 73.1, 31.2, 90. , 48.4, 40.6, 41.2, 31.7, 50. , 25.8,
#        69.8, 83.9,  3.5, 40. , 22.9,  0.5, 23.8, 49.9,  6.6,  1.9,  7.7,
#        31.8, 30.9, 68.5,  1.1,  1.2,  7.8, 15. ,  0.4,  3.3, 82.1, 54. ,
#        13.4,  1.6, 43.1, 34.8, 35.7, 21.4, 33.2, 67.6, 70.2, 19. , 33.9,
#        91.9,  8. , 61.5, 48. , 43.6,  8.3, 25.4, 11.2, 38.6, 25.9,  0.9,
#         7.2, 40.7,  0. , 87.6, 61.9, 74.1, 37.7, 57.7, 27.8, 30.1, 49.8,
#        42.3, 69.2, 60.4, 55.8, 42.8, 31.1, 88.4, 23.1, 40.4, 62. , 77.9,
#        10. ,  7.6, 63.4, 36.9, 32.9,  8.1, 98.3, 68.9,  2.7,  3. , 51.6,
# ...

# %%
#cuales son los 10 paises con la mayor area forestal

# %%
#cuales son los 10 paises con la mayor area forestal
df_af = df.groupby("forested_area")["country"].count().reset_index()
df_af
# Out:
#      forested_area  country
# 0              0.0        3
# 1              0.1        2
# 2              0.2        2
# 3              0.4        1
# 4              0.5        2
# ..             ...      ...
# 156           87.6        1
# 157           88.4        1
# 158           90.0        1
# 159           91.9        1
# 160           98.3        1
#
# [161 rows x 2 columns]

# %%
sns.regplot(data=df_af, x="forested_area", y="country");

# %%
#como se distribuye la densidad de poblacion entre los continentes

# %%
#Existe una relacion entre el PIB y la tasa de desempleo de los paises

# %%
df = pd.read_csv("files/world_data_full_apply_nulos.csv", index_col = 0)
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...
